# %%
import pandas as pd

# %%
customer = pd.read_csv('C:/Users/Khushi/OneDrive/Desktop/python/Machine_Learning/Data Files/1. ST Academy - Crash course and Regression files/Customer.csv')

# %%
customer.head()
# Out:
#   Customer ID    Customer Name    Segment  Age        Country  \
# 0    CG-12520      Claire Gute   Consumer   67  United States
# 1    DV-13045  Darrin Van Huff  Corporate   31  United States
# 2    SO-20335   Sean O'Donnell   Consumer   65  United States
# 3    BH-11710  Brosina Hoffman   Consumer   20  United States
# 4    AA-10480     Andrew Allen   Consumer   50  United States
#
#               City           State  Postal Code Region
# 0        Henderson        Kentucky        42420  South
# 1      Los Angeles      California        90036   West
# 2  Fort Lauderdale         Florida        33311  South
# 3      Los Angeles      California        90032   West
# 4          Concord  North Carolina        28027  South

# %%
customer = pd.read_csv('C:/Users/Khushi/OneDrive/Desktop/python/Machine_Learning/Data Files/1. ST Academy - Crash course and Regression files/Customer.csv', header=0)

# %%
customer.head()
# Out:
#   Customer ID    Customer Name    Segment  Age        Country  \
# 0    CG-12520      Claire Gute   Consumer   67  United States
# 1    DV-13045  Darrin Van Huff  Corporate   31  United States
# 2    SO-20335   Sean O'Donnell   Consumer   65  United States
# 3    BH-11710  Brosina Hoffman   Consumer   20  United States
# 4    AA-10480     Andrew Allen   Consumer   50  United States
#
#               City           State  Postal Code Region
# 0        Henderson        Kentucky        42420  South
# 1      Los Angeles      California        90036   West
# 2  Fort Lauderdale         Florida        33311  South
# 3      Los Angeles      California        90032   West
# 4          Concord  North Carolina        28027  South

# %%
customer = pd.read_csv('C:/Users/Khushi/OneDrive/Desktop/python/Machine_Learning/Data Files/1. ST Academy - Crash course and Regression files/Customer.csv', header=0, index_col=0)

# %% [markdown]
# * index_col is used to give the index, where value assigned to it is nothing but the index of column.
# * header is used to give the column entities and the value that assigned to it is nothing but the index of the row as index starts from 0

# %%
customer.head()
# Out:
#                Customer Name    Segment  Age        Country             City  \
# Customer ID
# CG-12520         Claire Gute   Consumer   67  United States        Henderson
# DV-13045     Darrin Van Huff  Corporate   31  United States      Los Angeles
# SO-20335      Sean O'Donnell   Consumer   65  United States  Fort Lauderdale
# BH-11710     Brosina Hoffman   Consumer   20  United States      Los Angeles
# AA-10480        Andrew Allen   Consumer   50  United States          Concord
#
#                       State  Postal Code Region
# Customer ID
# CG-12520           Kentucky        42420  South
# DV-13045         California        90036   West
# SO-20335            Florida        33311  South
# BH-11710         California        90032   West
# AA-10480     North Carolina        28027  South

# %%
customer.head(10)
# Out:
#                   Customer Name      Segment  Age        Country  \
# Customer ID
# CG-12520            Claire Gute     Consumer   67  United States
# DV-13045        Darrin Van Huff    Corporate   31  United States
# SO-20335         Sean O'Donnell     Consumer   65  United States
# BH-11710        Brosina Hoffman     Consumer   20  United States
# AA-10480           Andrew Allen     Consumer   50  United States
# IM-15070           Irene Maddox     Consumer   66  United States
# HP-14815          Harold Pawlan  Home Office   20  United States
# PK-19075              Pete Kriz     Consumer   46  United States
# AG-10270        Alejandro Grove     Consumer   18  United States
# ZD-21925     Zuschuss Donatelli     Consumer   66  United States
#
#                         City           State  Postal Code   Region
# Customer ID
# CG-12520           Henderson        Kentucky        42420    South
# DV-13045         Los Angeles      California        90036     West
# ...

# %%
customer_new = pd.read_csv('C:/Users/Khushi/OneDrive/Desktop/python/Machine_Learning/Data Files/1. ST Academy - Crash course and Regression files/Customer.csv', header=0)

# %% [markdown]
# * iloc is used to fetch the rows by using the index
# * loc is used to fetch the row by using the column id

# %%
customer_new.iloc[0]
# Out:
# Customer ID           CG-12520
# Customer Name      Claire Gute
# Segment               Consumer
# Age                         67
# Country          United States
# City                 Henderson
# State                 Kentucky
# Postal Code              42420
# Region                   South
# Name: 0, dtype: object

# %%
customer_new.iloc[0:3]
# Out:
#   Customer ID    Customer Name    Segment  Age        Country  \
# 0    CG-12520      Claire Gute   Consumer   67  United States
# 1    DV-13045  Darrin Van Huff  Corporate   31  United States
# 2    SO-20335   Sean O'Donnell   Consumer   65  United States
#
#               City       State  Postal Code Region
# 0        Henderson    Kentucky        42420  South
# 1      Los Angeles  California        90036   West
# 2  Fort Lauderdale     Florida        33311  South

# %%
customer_new.iloc[0:5:2]
# Out:
#   Customer ID   Customer Name   Segment  Age        Country             City  \
# 0    CG-12520     Claire Gute  Consumer   67  United States        Henderson
# 2    SO-20335  Sean O'Donnell  Consumer   65  United States  Fort Lauderdale
# 4    AA-10480    Andrew Allen  Consumer   50  United States          Concord
#
#             State  Postal Code Region
# 0        Kentucky        42420  South
# 2         Florida        33311  South
# 4  North Carolina        28027  South

# %%
customer.loc['CG-12520']
# Out:
# Customer Name      Claire Gute
# Segment               Consumer
# Age                         67
# Country          United States
# City                 Henderson
# State                 Kentucky
# Postal Code              42420
# Region                   South
# Name: CG-12520, dtype: object

# %%
customer.loc['CG-12520':'AA-10480']
# Out:
#                Customer Name    Segment  Age        Country             City  \
# Customer ID
# CG-12520         Claire Gute   Consumer   67  United States        Henderson
# DV-13045     Darrin Van Huff  Corporate   31  United States      Los Angeles
# SO-20335      Sean O'Donnell   Consumer   65  United States  Fort Lauderdale
# BH-11710     Brosina Hoffman   Consumer   20  United States      Los Angeles
# AA-10480        Andrew Allen   Consumer   50  United States          Concord
#
#                       State  Postal Code Region
# Customer ID
# CG-12520           Kentucky        42420  South
# DV-13045         California        90036   West
# SO-20335            Florida        33311  South
# BH-11710         California        90032   West
# AA-10480     North Carolina        28027  South

# %%
customer.iloc[0:2]
# Out:
#                Customer Name    Segment  Age        Country         City  \
# Customer ID
# CG-12520         Claire Gute   Consumer   67  United States    Henderson
# DV-13045     Darrin Van Huff  Corporate   31  United States  Los Angeles
#
#                   State  Postal Code Region
# Customer ID
# CG-12520       Kentucky        42420  South
# DV-13045     California        90036   West

# %%
customer.iloc[0:2:2]
# Out:
#             Customer Name   Segment  Age        Country       City     State  \
# Customer ID
# CG-12520      Claire Gute  Consumer   67  United States  Henderson  Kentucky
#
#              Postal Code Region
# Customer ID
# CG-12520           42420  South
